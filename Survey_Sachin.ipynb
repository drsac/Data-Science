# %%
## Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats # Many functions for probability distributions in python are in scipy.stats
from numpy import random
import os
import warnings
warnings.filterwarnings("ignore")

# %%
## load dataset
data = pd.read_csv('Survey.csv')

# %%
data.head()
# Out:
#    ID  Gender  Age   Class       Major Grad Intention  GPA  Employment  \
# 0   1  Female   20  Junior       Other            Yes  2.9   Full-Time
# 1   2    Male   23  Senior  Management            Yes  3.6   Part-Time
# 2   3    Male   21  Junior       Other            Yes  2.5   Part-Time
# 3   4    Male   21  Junior         CIS            Yes  2.5   Full-Time
# 4   5    Male   23  Senior       Other      Undecided  2.8  Unemployed
#
#    Salary  Social Networking  Satisfaction  Spending Computer  Text Messages
# 0    50.0                  1             3       350   Laptop            200
# 1    25.0                  1             4       360   Laptop             50
# 2    45.0                  2             4       600   Laptop            200
# 3    40.0                  4             6       600   Laptop            250
# 4    40.0                  2             4       500   Laptop            100

# %%
data.tail()
# Out:
#     ID  Gender  Age      Class                   Major Grad Intention  GPA  \
# 57  58  Female   21     Senior  International Business             No  2.4
# 58  59  Female   20     Junior                     CIS             No  2.9
# 59  60  Female   20  Sophomore                     CIS             No  2.5
# 60  61  Female   23     Senior              Accounting            Yes  3.5
# 61  62  Female   23     Senior       Economics/Finance             No  3.2
#
#    Employment  Salary  Social Networking  Satisfaction  Spending Computer  \
# 57  Part-Time    40.0                  1             3      1000   Laptop
# 58  Part-Time    40.0                  2             4       350   Laptop
# 59  Part-Time    55.0                  1             4       500   Laptop
# 60  Part-Time    30.0                  2             3       490   Laptop
# 61  Part-Time    70.0                  2             3       250   Laptop
#
#     Text Messages
# 57             10
# 58            250
# ...

# %%
## Summarize data set
data.describe(include ='all')
# Out:
#                ID  Gender        Age   Class                Major  \
# count   62.000000      62  62.000000      62                   62
# unique        NaN       2        NaN       3                    8
# top           NaN  Female        NaN  Senior  Retailing/Marketing
# freq          NaN      33        NaN      31                   14
# mean    31.500000     NaN  21.129032     NaN                  NaN
# std     18.041619     NaN   1.431311     NaN                  NaN
# min      1.000000     NaN  18.000000     NaN                  NaN
# 25%     16.250000     NaN  20.000000     NaN                  NaN
# 50%     31.500000     NaN  21.000000     NaN                  NaN
# 75%     46.750000     NaN  22.000000     NaN                  NaN
# max     62.000000     NaN  26.000000     NaN                  NaN
#
#        Grad Intention        GPA Employment     Salary  Social Networking  \
# count              62  62.000000         62  62.000000          62.000000
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Gender', 'Age', 'Class', 'Major', 'Grad Intention', 'GPA',
#        'Employment', 'Salary', 'Social Networking', 'Satisfaction', 'Spending',
#        'Computer', 'Text Messages'],
#       dtype='object')

# %% [markdown]
# ### 2.1. For this data, construct the following contingency tables (Keep Gender as row variable)
#
# #### 2.1.1. Gender and Major

# %%
data_crosstab = pd.crosstab(data['Gender'],
                            data['Major'])
data_crosstab
# Out:
# Major   Accounting  CIS  Economics/Finance  International Business  \
# Gender
# Female           3    3                  7                       4
# Male             4    1                  4                       2
#
# Major   Management  Other  Retailing/Marketing  Undecided
# Gender
# Female           4      3                    9          0
# Male             6      4                    5          3

# %% [markdown]
# #### 2.1.2. Gender and Grad Intention

# %%
data_crosstab = pd.crosstab(data['Gender'],
                            data['Grad Intention'])
data_crosstab
# Out:
# Grad Intention  No  Undecided  Yes
# Gender
# Female           9         13   11
# Male             3          9   17

# %% [markdown]
# #### 2.1.3. Gender and Employment

# %%
data_crosstab = pd.crosstab(data['Gender'],
                            data['Employment'])
data_crosstab
# Out:
# Employment  Full-Time  Part-Time  Unemployed
# Gender
# Female              3         24           6
# Male                7         19           3

# %% [markdown]
# #### 2.1.4. Gender and Computer

# %%
data_crosstab = pd.crosstab(data['Gender'],
                            data['Computer']) 
data_crosstab
# Out:
# Computer  Desktop  Laptop  Tablet
# Gender
# Female          2      29       2
# Male            3      26       0

# %% [markdown]
# ## 2.2. Assume that the sample is a representative of the population of CMSU. Based on the data, answer the following question:
#
# #### 2.2.1 What is the probability that a randomly selected CMSU student will be male?

# %%
data['Gender'].value_counts()
# Out:
# Female    33
# Male      29
# Name: Gender, dtype: int64

# %%
print('Probability that a randomly selected candidate will be male:',29/len(data['Gender']))
# Out:
# Probability that a randomly selected candidate will be male: 0.46774193548387094

# %% [markdown]
# #### 2.2.2 What is the probability that a randomly selected CMSU student will be female?

# %%
print('Probability that a randomly selected candidate will be female:',33/len(data['Gender']))
# Out:
# Probability that a randomly selected candidate will be female: 0.532258064516129

# %% [markdown]
# ### 2.3. Assume that the sample is a representative of the population of CMSU. Based on the data, answer the following question:
#
# #### 2.3.1 Find the conditional probability of different majors among the male students in CMSU.

# %%
data_crosstab = pd.crosstab(data['Gender'],
                            data['Major']) 
data_crosstab
# Out:
# Major   Accounting  CIS  Economics/Finance  International Business  \
# Gender
# Female           3    3                  7                       4
# Male             4    1                  4                       2
#
# Major   Management  Other  Retailing/Marketing  Undecided
# Gender
# Female           4      3                    9          0
# Male             6      4                    5          3

# %%
print('Among MALE candidates:')
print('Probability of Accounting:',4/29)
print('Probability of CIS:',1/29)
print('Probability of Economics/Finance:',4/29)
print('Probability of International Business:',2/29)
print('Probability of Management:',6/29)
print('Probability of Other:',4/29)
print('Probability of Retailing/Marketing:',5/29)
print('Probability of Undecided:',3/29)
print()
# Out:
# Among MALE candidates:
# Probability of Accounting: 0.13793103448275862
# Probability of CIS: 0.034482758620689655
# Probability of Economics/Finance: 0.13793103448275862
# Probability of International Business: 0.06896551724137931
# Probability of Management: 0.20689655172413793
# Probability of Other: 0.13793103448275862
# Probability of Retailing/Marketing: 0.1724137931034483
# Probability of Undecided: 0.10344827586206896

# %% [markdown]
# #### P (Major | Male) = P (Major ∩ male)/ P(male)

# %% [markdown]
# ####  2.3.2 Find the conditional probability of different majors among the female students of CMSU.

# %%
print('Among FEMALE candidates:')
print('Probability of Accounting:',3/33)
print('Probability of CIS:',3/33)
print('Probability of Economics/Finance	:',7/33)
print('Probability of International Business:',4/33)
print('Probability of Management:',4/33)
print('Probability of Other:',3/33)
print('Probability of Retailing/Marketing:',9/33)
print('Probability of Undecided:',0/33)
print()
# Out:
# Among FEMALE candidates:
# Probability of Accounting: 0.09090909090909091
# Probability of CIS: 0.09090909090909091
# Probability of Economics/Finance	: 0.21212121212121213
# Probability of International Business: 0.12121212121212122
# Probability of Management: 0.12121212121212122
# Probability of Other: 0.09090909090909091
# Probability of Retailing/Marketing: 0.2727272727272727
# Probability of Undecided: 0.0

# %% [markdown]
# #### P (Major | female) = P (Major ∩ female)/ P(female)

# %% [markdown]
# ### 2.4. Assume that the sample is a representative of the population of CMSU. Based on the data, answer the following question:
#
# #### 2.4.1 Find the probability That a randomly chosen student is a male and intends to graduate.

# %%
data_crosstab = pd.crosstab(data['Gender'],
                            data['Grad Intention']) 
data_crosstab
# Out:
# Grad Intention  No  Undecided  Yes
# Gender
# Female           9         13   11
# Male             3          9   17

# %%
print("P(graduate ∩ Male) = P (graduate | Male) x P (male) = ",(17/29) * (29/62))
# Out:
# P(graduate ∩ Male) = P (graduate | Male) x P (male) =  0.27419354838709675

# %% [markdown]
# #### 2.4.2 Find the probability that a randomly selected student is a female and does NOT have a laptop.

# %%
data_crosstab = pd.crosstab(data['Gender'],
                            data['Computer']) 
data_crosstab
# Out:
# Computer  Desktop  Laptop  Tablet
# Gender
# Female          2      29       2
# Male            3      26       0

# %%
print("P(laptop ∩ Female) = P (laptop | Female) x P (Female) = ",(4/33) * (33/62))
# Out:
# P(laptop ∩ Female) = P (laptop | Female) x P (Female) =  0.06451612903225806

# %% [markdown]
# ### 2.5. Assume that the sample is a representative of the population of CMSU. Based on the data, answer the following question:
#
# #### 2.5.1 Find the probability that a randomly chosen student is a male or has a full-time employment

# %%
data_crosstab = pd.crosstab(data['Gender'],
                            data['Employment'])
data_crosstab
# Out:
# Employment  Full-Time  Part-Time  Unemployed
# Gender
# Female              3         24           6
# Male                7         19           3

# %%
print("P(full-time ∩ Male) = P (full-time | Male) x P (male) = ",(7/29) * (29/62))
# Out:
# P(full-time ∩ Male) = P (full-time | Male) x P (male) =  0.11290322580645161

# %% [markdown]
# #### 2.5.2 Find the conditional probability that given a female student is randomly chosen, she is majoring in international business or management.

# %%
data_crosstab = pd.crosstab(data['Gender'],
                            data['Major'])
data_crosstab
# Out:
# Major   Accounting  CIS  Economics/Finance  International Business  \
# Gender
# Female           3    3                  7                       4
# Male             4    1                  4                       2
#
# Major   Management  Other  Retailing/Marketing  Undecided
# Gender
# Female           4      3                    9          0
# Male             6      4                    5          3

# %%
print("P(International Business ∩ Female) = P (International Business | Female) x P (Female) = ",(4/33) * (33/62))
# Out:
# P(International Business ∩ Female) = P (International Business | Female) x P (Female) =  0.06451612903225806

# %%
print("P(Management ∩ Female) = P (Management | Female) x P (Female) = ",(4/33) * (33/62))
# Out:
# P(Management ∩ Female) = P (Management | Female) x P (Female) =  0.06451612903225806

# %%
print("P(International Business/Management ∩ Female) = P (International Business/Management | Female) x P (Female) = ",(8/33) * (33/62))
# Out:
# P(International Business/Management ∩ Female) = P (International Business/Management | Female) x P (Female) =  0.12903225806451613

# %% [markdown]
# ### 2.6 Construct a contingency table of Gender and Intent to Graduate at 2 levels (Yes/No). The Undecided students are not considered now and the table is a 2x2 table. Do you think graduate intention and being female are independent events?

# %%
data_crosstab = pd.crosstab(data['Gender'],
                            data['Grad Intention']).drop('Undecided', axis = 1) 
data_crosstab
# Out:
# Grad Intention  No  Yes
# Gender
# Female           9   11
# Male             3   17

# %% [markdown]
# For 2 events to be independent, following condition is to be satified
#
# P(A ∩ B) = P(A) * P(B)
#
# So, P (Grad Intention ∩ Female) = P(Grad Intention) * P(Female)
#
# P(Female) = 33/62 = 0.532258064516129
#
# P(Grad Intention) = 28/62 = 0.45161290322580644
#
# P(Grad Intention) * P(Female) = 0.532258064516129 * 0.45161290322580644 = 0.24037460978147762
#
# P (Grad Intention ∩ Female) = 11/62 = 0.1774193548387097
#
# This is not independent events as probability multiplication of both events is not equal to combined event, so being a Graduate intention and being female candidate are not independent events.

# %% [markdown]
# ### 2.7 Note that there are four numerical (continuous) variables in the data set, GPA, Salary, Spending and Text Messages. Answer the following questions based on the data
#
# #### 2.7.1 If a student is chosen randomly, what is the probability that his/her GPA is less than 3?

# %%
data_crosstab = pd.crosstab(data['Gender'],
                            data['GPA']) 
data_crosstab
# Out:
# GPA     2.3  2.4  2.5  2.6  2.8  2.9  3.0  3.1  3.2  3.3  3.4  3.5  3.6  3.7  \
# Gender
# Female    1    1    2    0    1    3    5    2    4    3    2    4    1    2
# Male      0    0    4    2    2    1    2    5    2    2    5    2    2    0
#
# GPA     3.8  3.9
# Gender
# Female    1    1
# Male      0    0

# %%
data[data['GPA']<3]['GPA'].count()
# Out:
# 17

# %%
data[data['GPA']>=3]['GPA'].count()
# Out:
# 45

# %%
#### 2.7.1 If a student is chosen randomly, what is the probability that his/her GPA is less than 3?

print('Probability that a randomly selected candidate :',17/(17+45))
# Out:
# Probability that a randomly selected candidate : 0.27419354838709675

# %% [markdown]
# #### 2.7.2 Find conditional probability that a randomly selected male earns 50 or more. Find conditional probability that a randomly selected female earns 50 or more.

# %%
data[data['Salary']>=50]
# Out:
#     ID  Gender  Age      Class                   Major Grad Intention  GPA  \
# 0    1  Female   20     Junior                   Other            Yes  2.9
# 5    6  Female   22     Senior       Economics/Finance      Undecided  2.3
# 6    7  Female   21     Junior                   Other      Undecided  3.0
# 7    8  Female   22     Senior                   Other      Undecided  3.1
# 10  11  Female   23     Senior       Economics/Finance            Yes  2.8
# 14  15    Male   21     Senior              Management            Yes  3.2
# 16  17  Female   19     Junior                     CIS      Undecided  3.7
# 17  18    Male   21     Junior       Economics/Finance      Undecided  3.1
# 18  19    Male   19     Junior       Economics/Finance            Yes  3.5
# 19  20  Female   20     Junior              Management      Undecided  3.2
# 20  21  Female   22     Junior     Retailing/Marketing      Undecided  3.2
# ...

# %%
data_crosstab = pd.crosstab(data['Gender'],
                            data['Salary']<50)
data_crosstab
# Out:
# Salary  False  True
# Gender
# Female     18    15
# Male       14    15

# %%
data_crosstab = pd.crosstab(data['Gender'],
                            data['Salary']>=50)
data_crosstab
# Out:
# Salary  False  True
# Gender
# Female     15    18
# Male       15    14

# %%
print('Among Male and FEMALE candidates where their earnings are more than 50 or more :')

print('Probability of male earning more than 50 or more:',14/29)
print('Probability of female earning more than 50 or more:',18/33)
print()
# Out:
# Among Male and FEMALE candidates where their earnings are more than 50 or more :
# Probability of male earning more than 50 or more: 0.4827586206896552
# Probability of female earning more than 50 or more: 0.5454545454545454

# %%
print("P(Salary ∩ Male) = P (Salary | Male) x P (Male) = ",(14/29) * (29/62))
# Out:
# P(Salary ∩ Male) = P (Salary | Male) x P (Male) =  0.22580645161290322

# %%
print("P(Salary ∩ Female) = P (Salary | Female) x P (Female) = ",(18/33) * (33/62))
# Out:
# P(Salary ∩ Female) = P (Salary | Female) x P (Female) =  0.29032258064516125

# %% [markdown]
# ### 2.8.1 Note that there are four numerical (continuous) variables in the data set, GPA, Salary, Spending and Text Messages. For each of them comment whether they follow a normal distribution.

# %%
#sns.distplot(data['GPA'])
#plt.savefig('gpa_kde.jpg');
            
sns.distplot(data['GPA']);
plt.savefig('gpa_kde.jpg');

# %% [markdown]
# #### Graph is not Normal Distribution

# %%
sns.distplot(data['Salary']);
plt.savefig('sal_kde.jpg')

# %% [markdown]
# #### Graph is not Normal Distribution

# %%
sns.distplot(data['Spending']);
plt.savefig('sal_kde.jpg')

# %% [markdown]
# #### Graph is not Normal Distribution

# %%
sns.distplot(data['Text Messages']);
plt.savefig('sal_kde.jpg')

# %% [markdown]
# #### Graph is skewed left

# %% [markdown]
# #### 2.8.1 They do not follow a normal distribution for numerical (continuous) variables in the data set, GPA, Salary, Spending and Text Messages.

# %% [markdown]
# ### 2.8.2 Write a note summarizing your conclusions

# %% [markdown]
# #### Probability that a randomly selected candidate will be male: 0.46774193548387094
#
# #### The probability that a randomly chosen student is a male and intends to graduate is 0.27419354838709675
#
# #### The probability that a randomly selected student is a female and does NOT have a laptop is 0.06451612903225806
#
# #### The probability that a randomly chosen student is a male or has a full-time employment is 0.11290322580645161
#
# #### The conditional probability that given a female student is randomly chosen, she is majoring in international business or management  is 0.12903225806451613
#
# #### Being a Graduate intention and being female candidate are not independent events.
#
# #### Probability that a randomly selected candidate that his/her GPA is less than 3  : 0.27419354838709675
#
# #### Probability of male earning more than 50 or more: 0.4827586206896552
#
# #### Probability of female earning more than 50 or more: 0.5454545454545454
